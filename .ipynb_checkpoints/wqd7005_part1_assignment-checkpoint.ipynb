# %%
# Studnet Name:Alireza Ghanbarzadeh
# Matric No: WQD170061

import urllib
from urllib.request import Request,urlopen
import json

# %%
url = "https://advcharts.investing.com/advinion2016/advanced-charts/1/1/8/GetRecentHistory?strSymbol=8836&iTop=1500&strPriceType=bid&strFieldsMode=allFields&strExtraData=lang_ID=1&strTimeFrame=1D"
results = urllib.request.urlopen(url)
decoded_data = results.read().decode("utf-8")
json_data = json.loads(decoded_data)
try:
     list_data = json_data["data"]            
except KeyError:
    print("Key Error!")

# %%
list_data
# Out:
# [{'date': '2015-08-21 00:00:00',
#   'open': 15.300999641418,
#   'close': 15.300999641418,
#   'low': 15.300999641418,
#   'high': 15.300999641418,
#   'volume': 17639,
#   'volume_ac': 0,
#   'volume_open': 0,
#   'related_ec_event_id': None,
#   'related_news_items': None,
#   'start_timestamp': 1440115200,
#   'split': None,
#   'dividend': None,
#   'related_patterns_high': '',
#   'related_patterns_med': '9'},
#  {'date': '2015-08-23 00:00:00',
#   'open': 15.319999694824,
#   'close': 15.340000152588,
#   'low': 15.27499961853,
#   'high': 15.380000114441,
#   'volume': 0,
#   'volume_ac': 0,
#   'volume_open': 0,
#   'related_ec_event_id': None,
#   'related_news_items': None,
#   'start_timestamp': 1440288000,
#   'split': None,
#   'dividend': None,
#   'related_patterns_high': '',
#   'related_patterns_med': ''},
#  {'date': '2015-08-24 00:00:00',
#   'open': 14.762000083923,
#   'close': 14.762000083923,
#   'low': 14.762000083923,
#   'high': 14.762000083923,
# ...
